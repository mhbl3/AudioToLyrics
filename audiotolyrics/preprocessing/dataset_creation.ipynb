# %%
cd "/content/drive/My Drive/audioToLyrics"
# Out:
# /content/drive/My Drive/audioToLyrics

# %%
# !git clone https://github.com/JayChen35/spotify-to-mp3-python.git
# Out:
# Cloning into 'spotify-to-mp3-python'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 13 (delta 2), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.

# %%
# !pip3 install spotipy && pip3 install youtube_dl && pip3 install youtube_search
# Out:
# ...
#      |████████████████████████████████| 1.8MB 5.6MB/s
# ...

# %%
# !python3 -m pip install --upgrade youtube-dlc # required after a download issue was encountered
# Out:
# ...
#      |████████████████████████████████| 1.8MB 4.5MB/s
# ...

# %%
cd "/content/drive/My Drive/audioToLyrics/preprocessing"
# Out:
# /content/drive/My Drive/audioToLyrics/preprocessing

# %%
# Note:The redirect link does not open a window when using Google Colabs
# this cell should be run on a notebook on your machine or the file ".cache-username" should be in the 
# same folder as search_add_to_playlist.py
# You can get this cache by running the code on your machine, it will be generated
# !python -u search_add_to_playlist.py
# Out:
# Cliend ID: 79768419b4ed4bb7a9f791715b7b2768
# Client Secret: 3438e9ddcbd34085b7d0eb9c63e9ec03
# Search key word: rap
# Searching for tracks
# Number of tracks: 300
# Number of tracks: 300
# username: makybl
# Adding tracks to playlist
# Done!

# %%
# Note:The redirect link does not open a window when using Google Colabs
# this cell should be run on a notebook on your machine or the file ".cache-username" should be in the 
# same folder as search_add_to_playlist.py
# You can get this cache by running the code on your machine, it will be generated
# !python -u search_add_to_playlist.py
# Out:
# Cliend ID: 79768419b4ed4bb7a9f791715b7b2768
# Client Secret: 3438e9ddcbd34085b7d0eb9c63e9ec03
# Search key word: country
# Searching for tracks
# Number of tracks: 100
# username: makybl
# Adding tracks to playlist
# Done!

# %%
cd "/content/drive/My Drive/audioToLyrics"
# Out:
# /content/drive/My Drive/audioToLyrics

# %%
# !python3 ./spotify_to_mp3_python/spotify_to_mp3.py
# Out:
# Please read README.md for use instructions.
# Client ID: 79768419b4ed4bb7a9f791715b7b2768
# Client secret: 3438e9ddcbd34085b7d0eb9c63e9ec03
# Spotify username: makybl
# Playlist URI (excluding "spotify:playlist:"): 3YXnAB19mU5QDha8gPN5Jl
# Writing 400 tracks to audioToLyrics_rap.txt.
# Skipping Rap God
# Initiating download for Machine Gun Kelly - RAP DEVIL.
# [youtube] Fp0BScQSSvg: Downloading webpage
# [download] Destination: Machine Gun Kelly 'Rap Devil' (Eminem Diss) (WSHH Exclusive - Official Music Video)-Fp0BScQSSvg.webm
# [download] 100% of 4.69MiB in 00:00
# [ffmpeg] Destination: Machine Gun Kelly 'Rap Devil' (Eminem Diss) (WSHH Exclusive - Official Music Video)-Fp0BScQSSvg.mp3
# Deleting original file Machine Gun Kelly 'Rap Devil' (Eminem Diss) (WSHH Exclusive - Official Music Video)-Fp0BScQSSvg.webm (pass -k to keep)
# Initiating download for Lil Darkie - rap music.
# [youtube] B6DGB0oESzQ: Downloading webpage
# ...

# %%
# !python3 ./spotify_to_mp3_python/spotify_to_mp3.py
# Out:
# Please read README.md for use instructions.
# Client ID: 79768419b4ed4bb7a9f791715b7b2768
# Client secret: 3438e9ddcbd34085b7d0eb9c63e9ec03
# Spotify username: makybl
# Playlist URI (excluding "spotify:playlist:"): 7kgsLrjLRwimdBwhxuqS82
# Writing 100 tracks to audioToLyrics_country.txt.
# Initiating download for Luke Bryan - Country Girl (Shake It For Me).
# [youtube] 7HX4SfnVlP4: Downloading webpage
# [download] Destination: Luke Bryan - Country Girl (Shake It For Me) (Official Music Video)-7HX4SfnVlP4.webm
# [download] 100% of 4.50MiB in 00:00
# [ffmpeg] Destination: Luke Bryan - Country Girl (Shake It For Me) (Official Music Video)-7HX4SfnVlP4.mp3
# Deleting original file Luke Bryan - Country Girl (Shake It For Me) (Official Music Video)-7HX4SfnVlP4.webm (pass -k to keep)
# Initiating download for Aaron Lewis - Country Boy (feat. George Jones & Charlie Daniels).
# [youtube] vsQzw_Ax8Cw: Downloading webpage
# ...

# %%
# !pip install lyricsgenius
# Out:
# ...
#      |████████████████████████████████| 51kB 2.4MB/s
# ...

# %%
# !python3 ./preprocessing/get_lyrics.py

# %%
# !python3 ./preprocessing/get_lyrics.py
# Out:
# Directory for music: ./audioToLyrics_country
# Genius Client Access: UipY_uaDfhwaRsSqfpTLrybZk4VBJ36bB6ZKhqHTGp83roX3J4FuN-gbsMkYktV_
# Searching for " Country Girl " by Luke Bryan ...
# Done.
# Searching for " 'Country Boy' " by Aaron Lewis ...
# Done.
# Searching for " Country Grammar (Hot Shit)" by Nelly ...
# Done.
# Searching for " Country Song" by Seether ...
# Done.
# Searching for " Country Squire " by Tyler Childers ...
# Done.
# Searching for " Country Must Be Country Wide" by Brantley Gilbert ...
# Done.
# Searching for " Country Boy " by Alan Jackson ...
# Done.
# Searching for " 10 Hours of Countryside Rain for Sleep" by Heavy Rain and Wind Sounds Black Screen ...
# Done.
# Searching for " 10 Hours of Countryside Rain for Sleep" by Heavy Rain and Wind Sounds Black Screen ...
# Done.
# Searching for " Countryside (Audio)" by Florida Georgia Line ...
# No results found for: 'Countryside (Audio) Florida Georgia Line'
# Skipping  Countryside (Audio) by Florida Georgia Line
# ...

# %%
import lyricsgenius
client_access_token = input("Genius Client Access: ") 
genius = lyricsgenius.Genius(client_access_token)
song_genius = genius.search_song(" Country girl", "Luke Bryan ")
# Out:
# Genius Client Access: UipY_uaDfhwaRsSqfpTLrybZk4VBJ36bB6ZKhqHTGp83roX3J4FuN-gbsMkYktV_
# Searching for " Country girl" by Luke Bryan ...
# Done.

# %%
song_genius.lyrics
# Out:
# "[Intro]\nHey girl, go on now\nYou know you've got everybody looking\n\n[Verse 1]\nGot a little boom in my big truck\nGonna open up the doors and turn it up\nGonna stomp my boots in the Georgia mud\nGonna watch you make me fall in love\nGet up on the hood of my daddy's tractor\nUp on the toolbox, it don't matter\nDown on the tailgate, girl I can't wait\nTo watch you do your thing\n\n[Pre-Chorus]\nShake it for the young bucks sittin' in the honky-tonks\nFor the rednecks rockin' 'til the break of dawn\nFor the DJ spinnin' that country song\nCome on, come on, come on\nShake it for the birds, shake it for the bees\nShake it for the catfish swimming down deep in the creek\nFor the crickets and the critters and the squirrels\nShake it to the moon, shake it for me girl, aww\n\n[Chorus]\nCountry girl, shake it for me girl\nShake it for me girl, shake it for me\nCountry girl, shake it for me girl\nShake it for me girl, shake it for me\n\n[Verse 2]\nSomebody's sweet little farmer's child\nWith
# ...
